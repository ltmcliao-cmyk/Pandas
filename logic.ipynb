# %%
# %pip install pandas
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# 模擬培訓班資料
data = {
    'name': ['Lutomica', 'Katie', 'Jim', 'Bob', 'Alice', 'Nipple Cat'],
    'dept': ['Data Eng', 'Marketing', 'FinTech', 'Data Eng', 'FinTech', 'Data Eng'],
    'score': [95, 88, np.nan, 70, np.nan, 99],  # 包含 NaN 空值
    'project_completed': [True, True, False, False, True, True],
    'hours_spent': [120, 80, 10, 45, 110, 150]
}

df = pd.DataFrame(data)
print("--- 原始資料 ---")
print(df)
# Out:
# --- 原始資料 ---
#          name       dept  score  project_completed  hours_spent
# 0    Lutomica   Data Eng   95.0               True          120
# 1       Katie  Marketing   88.0               True           80
# 2         Jim    FinTech    NaN              False           10
# 3         Bob   Data Eng   70.0              False           45
# 4       Alice    FinTech    NaN               True          110
# 5  Nipple Cat   Data Eng   99.0               True          150

# %%
"""
isin
"""
df["dept"].isin(["Data Eng","FinTech"])
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# Name: dept, dtype: bool
